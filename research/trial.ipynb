# %%
# %pwd
# Out:
# 'd:\\INTERNSHIP\\AI_Document_Summarizer_QA_System\\research'

# %%
import os
from dotenv import load_dotenv
from typing import TypedDict
from langchain_groq import ChatGroq
from pydantic import BaseModel, Field

from AI_Document_Summarizer_QA_System.components.stage_01_document_loader import DocumentLoader
from AI_Document_Summarizer_QA_System.components.stage_02_text_splitter import TextSplitter
from AI_Document_Summarizer_QA_System.components.stage_03_store_index import VectorIndex
from AI_Document_Summarizer_QA_System.components.stage_04_RAG import RAGPipeline
from AI_Document_Summarizer_QA_System.components.stage_05_Output import SummaryGenerator, OutputFormatter

load_dotenv()
# Out:
# True

# %%
class Question_Answer_State(BaseModel):
    question : str = Field(description="Question regarding the Document Provided by the user") 
    answer : str  = Field(description= "Answer given Provided by the LLM from the Document")

# %%
llm =  ChatGroq(model_name = "Gemma2-9b-It")

model = llm.with_structured_output(Question_Answer_State)

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\INTERNSHIP\\AI_Document_Summarizer_QA_System'

# %% [markdown]
# # Document Loader

# %%
loader = DocumentLoader()
pdf_path = "Data/Capstone_Project_Artificial _Intelligence.pdf"
text = loader.load(pdf_path)
print(text[:700])
# Out:
# Operations@learnnex.in www.LearnNex.in
# 2. AI-Powered Personal Health Tracker:
# Description:
# Use AI to monitor and predict health patterns using fitness tracker data, diet, and
# sleep logs
# Steps:
# 1.Collect data (manual entry or from APIs like Fitbit or Apple Health).
# 2.Use Pandas to clean and analyze data.
# 3.Visualize trends using Matplotlib/Plotly.
# CAPSTONE PROJECT
# Artificial Intelligence :-
# 1. AI Chatbot using LLMs:
# Description: Build a custom chatbot using open-source LLMs like Meta’s LLaMA, Mistral, orintegrate with OpenAI API for a domain-specific assistant (e.g., legal, medical,education).
# Steps:1.Learn Python (focus on data structures, classes, API usage).2.Study how chatbots work (rule

# %% [markdown]
# # Text Splitter

# %%
splitter = TextSplitter(chunk_size=800, chunk_overlap=200)
chunks = splitter.split_documents(text)

print("Chunks created:", len(chunks))
print(chunks[0][:300])
# Out:
# Chunks created: 4
# Operations@learnnex.in www.LearnNex.in
# 2. AI-Powered Personal Health Tracker:
# Description:
# Use AI to monitor and predict health patterns using fitness tracker data, diet, and
# sleep logs
# Steps:
# 1.Collect data (manual entry or from APIs like Fitbit or Apple Health).
# 2.Use Pandas to clean and analyze

# %% [markdown]
# # Vector Store

# %%
indexer = VectorIndex()
result = indexer.add_documents(chunks)
result
# Out:
# {'status': 'success', 'chunks_added': 4}

# %% [markdown]
# # Rag Pipeline

# %%
rag = RAGPipeline()

query = "What is the third capstone project described in the document?"
rag_result = rag.ask(query)

print(rag_result)

print("-----------------------------------------\n")

print(rag_result['answer'])
# Out:
# {'answer': 'The third capstone project described in the document is the "AI Image Generator", which generates images from text using Stable Diffusion or DALL·E with custom styles.', 'sources': ['Operations@learnnex.in www.LearnNex.in\n3. AI Image Generator:\nDescription:\n Generate images from text using Stable Diffusion or DALL·E with custom styles.\nSteps:\n1.Install and run pre-trained Stable Diffusion models using diffusers.\n2.Prompt engineering to guide image generation.\n3.Use gradio to build a web UI.\nAs part of your internship program, you are required to prepare any two projects. These projects will form an important\ncomponent of your internship evaluation and should reflect both your theoretical knowledge and practical application.\n4. AI Document Summarizer & Q&A System:\nDescription:\n Create a system that can take PDFs (like research papers or legal docs), summarize\nthem, and answer questions.\nSteps:\n1.Use LangChain or LlamaIndex to create a RAG (Retrieval-Augmented Generation)\npipeline.\n2.Add memory, citations, and multiple documents support.\n3.Build a web app with Flask or Next.js for users to upload docs and chat.\nOperations@learnnex.in www.LearnNex.in', 'Operations@learnnex.in www.LearnNex.in\n3. AI Image Generator:\nDescription:\n Generate images from text using Stable Diffusion or DALL·E with custom styles.\nSteps:\n1.Install and run pre-trained Stable Diffusion models using diffusers.\n2.Prompt engineering to guide image generation.\n3.Use gradio to build a web UI.\nAs part of your internship program, you are required to prepare any two projects. These projects will form an important\ncomponent of your internship evaluation and should reflect both your theoretical knowledge and practical application.\n4. AI Document Summarizer & Q&A System:\nDescription:\n Create a system that can take PDFs (like research papers or legal docs), summarize\nthem, and answer questions.\nSteps:\n1.Use LangChain or LlamaIndex to create a RAG (Retrieval-Augmented Generation)\npipeline.\n2.Add memory, citations, and multiple documents support.\n3.Build a web app with Flask or Next.js for users to upload docs and chat.\nOperations@learnnex.in www.LearnNex.in', 'Operations@learnnex.in www.LearnNex.in\n3. AI Image Generator:\nDescription:\n Generate images from text using Stable Diffusion or DALL·E with custom styles.\nSteps:\n1.Install and run pre-trained Stable Diffusion models using diffusers.\n2.Prompt engineering to guide image generation.\n3.Use gradio to build a web UI.\nAs part of your internship program, you are required to prepare any two projects. These projects will form an important\ncomponent of your internship evaluation and should reflect both your theoretical knowledge and practical application.\n4. AI Document Summarizer & Q&A System:\nDescription:\n Create a system that can take PDFs (like research papers or legal docs), summarize\nthem, and answer questions.\nSteps:\n1.Use LangChain or LlamaIndex to create a RAG (Retrieval-Augmented Generation)\npipeline.\n2.Add memory, citations, and multiple documents support.\n3.Build a web app with Flask or Next.js for users to upload docs and chat.\nOperations@learnnex.in www.LearnNex.in']}
# -----------------------------------------
#
# The third capstone project described in the document is the "AI Image Generator", which generates images from text using Stable Diffusion or DALL·E with custom styles.

# %% [markdown]
# # Output Format

# %%
groq_key = os.getenv("GROQ_API_KEY")

summarizer = SummaryGenerator(groq_key)
formatter = OutputFormatter()

summaries = summarizer.generate_all(text)

print("--------------------------------\n")

print("Short Summary \n\n", summaries['short'])

print("--------------------------------\n")

print("Medium Summary \n\n", summaries['medium'])

print("--------------------------------\n")

print("Detailed Summary \n\n", summaries['detailed'])
# Out:
# --------------------------------
#
# Short Summary
#
#  Here is a 4-6 sentence TL;DR summary of the document:
# The document outlines five AI-powered project ideas for an internship program, including a personal health tracker, AI chatbot, AI image generator, AI document summarizer, and AI music generator. Each project has a detailed description and step-by-step guide on how to implement it. The projects require a range of skills, including data analysis, natural language processing, and machine learning. Interns are required to complete any two of these projects as part of their evaluation. The projects aim to test both theoretical knowledge and practical application of AI concepts. By completing these projects, interns can demonstrate their skills and understanding of AI technologies.
# --------------------------------
#
# Medium Summary
#
#  Here is a structured summary of the document in 3 sections:
#
# **1. Overview**
# The document outlines various AI-powered projects that can be undertaken as part of an internship program. The projects are designed to test both theoretical knowledge and practical application of AI concepts. Interns are required to prepare any two projects from the given list, which will form an important component of their internship evaluation.
#
# **2. Key Concepts**
# The key concepts covered in the document include:
# * AI-powered personal health tracking using fitness tracker data, diet, and sleep logs
# * Building custom chatbots using open-source LLMs
# * AI image generation using Stable Diffusion or DALL·E
# * AI document summarization and Q&A systems
# * AI music generation and composition using models like MusicGen, Riffusion, or Jukebox
# * Natural Language Processing (NLP) and machine learning techniques
#
# **3. Important Steps**
# The important steps to undertake these projects include:
# * Collecting and analyzing data using tools like Pandas and Matplotlib
# * Using pre-trained models and APIs like OpenAI, Hugging Face, and LangChain
# * Building web applications using frameworks like Flask or Next.js
# * Training and fine-tuning AI models using datasets and libraries like MIDI and Tortoise TTS
# * Implementing prompt engineering and memory augmentation techniques to improve AI model performance.
# --------------------------------
#
# Detailed Summary
#
#  # AI-Powered Projects for Internship Evaluation
# ## Overview
# The document outlines five AI-powered projects that interns can work on as part of their evaluation. These projects cover a range of applications, including personal health tracking, chatbots, image generation, document summarization, and music generation. The goal is to demonstrate both theoretical knowledge and practical application of AI concepts.
#
# ## Section-wise Breakdown
# The document is divided into five sections, each describing a different project:
# 1. **AI-Powered Personal Health Tracker**: This project involves using AI to monitor and predict health patterns based on fitness tracker data, diet, and sleep logs.
# 2. **AI Chatbot using LLMs**: This project requires building a custom chatbot using open-source LLMs or integrating with OpenAI API for a domain-specific assistant.
# 3. **AI Image Generator**: This project involves generating images from text using Stable Diffusion or DALL·E with custom styles.
# 4. **AI Document Summarizer & Q&A System**: This project requires creating a system that can summarize PDF documents and answer questions based on the content.
# 5. **AI Music Generator / Composer**: This project involves generating music from text prompts or mood using AI models like MusicGen, Riffusion, or Jukebox.
#
# ## Key Ideas
# The key ideas behind these projects include:
# * **Data analysis and visualization**: Using tools like Pandas and Matplotlib to analyze and visualize data.
# * **Natural Language Processing (NLP)**: Using LLMs and transformers to build chatbots and document summarizers.
# * **Computer Vision**: Using Stable Diffusion and DALL·E to generate images from text.
# * **Music Generation**: Using AI models like MusicGen, Riffusion, and Jukebox to generate music from text prompts or mood.
#
# ## Methods / Steps
# The steps involved in each project vary, but some common methods include:
# * **Data collection and preprocessing**: Collecting and cleaning data for analysis and visualization.
# * **Model training and deployment**: Training and deploying AI models using frameworks like Hugging Face and OpenAI API.
# * **Web development**: Building web applications using frameworks like Flask and Next.js to interact with users.
# * **Prompt engineering**: Guiding image generation using prompt engineering techniques.
#
# ## Example Use-Cases
# Example use-cases for these projects include:
# * **Personalized health tracking**: Using AI to monitor and predict health patterns for individuals.
# * **Domain-specific chatbots**: Building chatbots for specific domains like law, medicine, or education.
# * **Custom image generation**: Generating images from text for applications like advertising or art.
# * **Document summarization**: Summarizing long documents like research papers or legal documents.
# * **Music composition**: Generating music from text prompts or mood for applications like film scoring or music production.
#
# ## Final Takeaways (TL;DR)
# The document outlines five AI-powered projects for internship evaluation, covering personal health tracking, chatbots, image generation, document summarization, and music generation. These projects require a range of skills, including data analysis, NLP, computer vision, and web development. By working on these projects, interns can demonstrate their theoretical knowledge and practical application of AI concepts, and develop valuable skills for their future careers.

# %% [markdown]
# # Final Testing

# %%
rag_test = rag.ask("Can you summarize the first two projects described in the document?")
med_sum = summarizer.medium_summary(text)

formatter.build_response(
    answer=rag_test["answer"],
    sources=rag_test["sources"],
    summary=med_sum
)

print(med_sum)
# Out:
# Here is a structured summary of the document in 3 sections:
#
# **1. Overview**
# The document outlines five AI-powered projects that can be undertaken as part of an internship program. These projects aim to apply theoretical knowledge and practical skills in artificial intelligence, machine learning, and data analysis. The projects are designed to evaluate the intern's understanding of AI concepts and their ability to implement them in real-world applications.
#
# **2. Key Concepts**
# The key concepts covered in the document include:
# * AI-powered personal health tracking using fitness tracker data, diet, and sleep logs
# * Building custom chatbots using open-source LLMs and integrating with OpenAI API
# * Generating images from text using Stable Diffusion or DALL·E
# * Creating a document summarizer and Q&A system using LangChain or LlamaIndex
# * Generating music from text prompts or mood using AI models like MusicGen, Riffusion, or Jukebox
# * Using libraries and frameworks such as Pandas, Matplotlib, Plotly, Hugging Face, and Gradio
#
# **3. Important Steps**
# The important steps to undertake these projects include:
# * Collecting and cleaning data using APIs or manual entry
# * Analyzing and visualizing data using Pandas, Matplotlib, and Plotly
# * Building and training AI models using Hugging Face, OpenAI API, and other libraries
# * Creating web UIs using Gradio, Flask, or Next.js
# * Integrating multiple components and models to create a comprehensive system
# * Testing and evaluating the performance of the AI models and systems.
